# %% [markdown]
# # Data Analysis Homework

# %%
# data analysis and wrangling
import pandas as pd
import numpy as np

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline


# Read the csv file and store it in dataframe
df_apps = pd.read_csv("../input/google-play-store-apps/googleplaystore.csv")

#We need to drop this sample as it's clearly corrupted.
df_apps = df_apps.drop(10472).reset_index().drop("index", axis=1)

# %% [markdown]
# # Exercise 1: Show all the rows in df_apps with Rating less than 4

# %%
df_apps.loc[df_apps.Rating < 4]
# Out:
#                                            App             Category  Rating  \
# 1                          Coloring book moana       ART_AND_DESIGN     3.9
# 6      Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN     3.8
# 15             Learn To Draw Kawaii Characters       ART_AND_DESIGN     3.2
# 28                       Pencil Sketch Drawing       ART_AND_DESIGN     3.9
# 35            How to draw Ladybug and Cat Noir       ART_AND_DESIGN     3.8
# ...                                        ...                  ...     ...
# 10781                  Trine 2: Complete Story                 GAME     3.8
# 10818                                Fanfic-FR  BOOKS_AND_REFERENCE     3.3
# 10827                  Manga-FR - Anime Vostfr               COMICS     3.4
# 10829                        News Minecraft.fr   NEWS_AND_MAGAZINES     3.8
# 10831                                 FR Tides              WEATHER     3.8
#
#       Reviews  Size  Installs  Type   Price Content Rating  \
# 1         967   14M  500,000+  Free       0       Everyone
# 6         178   19M   50,000+  Free       0       Everyone
# 15         55  2.7M    5,000+  Free       0       Everyone
# 28        136  4.6M   10,000+  Free       0       Everyone
# 35        564  9.2M  100,000+  Free       0       Everyone
# ...       ...   ...       ...   ...     ...            ...
# 10781     252   11M   10,000+  Paid  $16.99           Teen
# 10818      52  3.6M    5,000+  Free       0           Teen
# 10827     291   13M   10,000+  Free       0       Everyone
# 10829     881  2.3M  100,000+  Free       0       Everyone
# 10831    1195  582k  100,000+  Free       0       Everyone
#
#                           Genres       Last Updated Current Ver   Android Ver
# 1      Art & Design;Pretend Play   January 15, 2018       2.0.0  4.0.3 and up
# 6                   Art & Design     April 26, 2018         1.1  4.0.3 and up
# 15                  Art & Design       June 6, 2018         NaN    4.2 and up
# 28                  Art & Design      July 12, 2018         6.0    2.3 and up
# 35                  Art & Design      July 11, 2018         2.1    4.1 and up
# ...                          ...                ...         ...           ...
# 10781                     Action  February 27, 2015        2.22    5.0 and up
# 10818          Books & Reference     August 5, 2017       0.3.4    4.1 and up
# 10827                     Comics       May 15, 2017       2.0.1    4.0 and up
# 10829           News & Magazines   January 20, 2014         1.5    1.6 and up
# 10831                    Weather  February 16, 2014         6.0    2.1 and up
#
# [1998 rows x 13 columns]

# %% [markdown]
# # Exercise 2: Drop "Android Ver" and "Genres" column

# %%
#Let's drop "Android Ver" and "Genres" columns
df_apps.drop("Android Ver", axis=1, inplace=True)
df_apps.drop("Genres", axis=1, inplace=True)

# Check all the columns
df_apps.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Last Updated', 'Current Ver'],
#       dtype='object')

# %% [markdown]
# # Exercise 3: Write some python code that prints the number of unique values for each column

# %%
# Print unique values in each column, we use alternative way to print them in a "for" loop
for i in df_apps.columns:
    print ("# of Unique Values in Column", i, "is", df_apps[i].nunique())
# Out:
# # of Unique Values in Column App is 9659
# # of Unique Values in Column Category is 33
# # of Unique Values in Column Rating is 39
# # of Unique Values in Column Reviews is 6001
# # of Unique Values in Column Size is 461
# # of Unique Values in Column Installs is 21
# # of Unique Values in Column Type is 2
# # of Unique Values in Column Price is 92
# # of Unique Values in Column Content Rating is 6
# # of Unique Values in Column Last Updated is 1377
# # of Unique Values in Column Current Ver is 2831

# %% [markdown]
# # Exercise 4: Try to plot the below chart using only df_apps dataframe and in 2 lines of code

# %%
# Plot using only "df_apps" and limit the boundries
ax1 = df_apps[['Category','Rating']].groupby('Category').mean().sort_values("Rating").plot(kind='bar', figsize=(20,10))
ax1.set_ylim(3.5,5)
# Out:
# (3.5, 5.0)

# %% [markdown]
# # Murat Saskin
